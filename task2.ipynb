# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayameena832/Is-the-road-safe-Project/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. import the dataset**

# %%
# !pip install -q kaggle

# %%
  from google.colab import files
  files.upload()
# Out:
#      <input type="file" id="files-8f849e0a-ecfe-4d12-a123-edfac5f48130" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f849e0a-ecfe-4d12-a123-edfac5f48130">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"jojospace","key":"dc55d1d2a0684d06fdc3c8449a0cd0f6"}'}

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                                   title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# victorsoeiro/netflix-tv-shows-and-movies                              Netflix TV Shows and Movies                           2MB  2022-05-15 00:01:23           5851        185  1.0
# surajjha101/stores-area-and-sales-data                                Supermarket store branches sales analysis            10KB  2022-04-29 11:10:16           5279        156  1.0
# devansodariya/student-performance-data                                Student Performance Dataset                           7KB  2022-05-26 13:55:09           2236        111  0.9705882
# ...

# %%
! kaggle datasets download -d l3llff/flowers
# Out:
# flowers.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
! unzip flowers.zip

# %%
# importing libraries
import tensorflow as tf  
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import glob

# %% [markdown]
# **2. use glob and import all files**

# %%
flwrs = glob.glob(r"/content/flowers/*/**")

# %%
len(flwrs)
# Out:
# 15740

# %%
flwrs
# Out:
# ['/content/flowers/bellflower/5895154421_251e51398e_c.jpg',
#  '/content/flowers/bellflower/29419015563_bfb22ec6ce_c.jpg',
#  '/content/flowers/bellflower/14384510142_c25029e910_c.jpg',
#  '/content/flowers/bellflower/48320660927_4d37d2b6f1_c.jpg',
#  '/content/flowers/bellflower/7372368136_8de1074fc9_c.jpg',
#  '/content/flowers/bellflower/4840899494_37c1a6bc5b_c.jpg',
#  '/content/flowers/bellflower/3713451620_4084d5047d_c.jpg',
#  '/content/flowers/bellflower/14394980677_2b353c0836_c.jpg',
#  '/content/flowers/bellflower/20546323969_8b71e76d5d_c.jpg',
#  '/content/flowers/bellflower/3716155435_2327645296_c.jpg',
#  '/content/flowers/bellflower/50730716396_eb0765247c_c.jpg',
#  '/content/flowers/bellflower/48056194676_064c00ebaf_c.jpg',
#  '/content/flowers/bellflower/48357470851_4b35a43fde_c.jpg',
#  '/content/flowers/bellflower/36003475006_c6c78e5241_c.jpg',
#  '/content/flowers/bellflower/18613989294_e3162947b9_c.jpg',
# ...

# %% [markdown]
# **3. randomize the data**

# %%
from random import shuffle
shuffle(flwrs)
flwrs
# Out:
# ['/content/flowers/iris/906532290_e71f796d2c_c.jpg',
#  '/content/flowers/dandelion/505112282_0f537ffa42_c.jpg',
#  '/content/flowers/iris/7265022286_bdcbf5bf34_c.jpg',
#  '/content/flowers/coreopsis/9480866592_6686c22e02_c.jpg',
#  '/content/flowers/carnation/850416779_e9331d6d33_c.jpg',
#  '/content/flowers/california_poppy/49721116126_26ed9ddde1_c.jpg',
#  '/content/flowers/dandelion/14098770588_6a9ab28557_c.jpg',
#  '/content/flowers/magnolia/51996149390_46eeb29534_c.jpg',
#  '/content/flowers/carnation/16847349070_2255276577_c.jpg',
#  '/content/flowers/calendula/2279523280_27bb25fa9b_c.jpg',
#  '/content/flowers/calendula/28851355744_fcb4f95e74_c.jpg',
#  '/content/flowers/bellflower/3670469366_11df88953e_c.jpg',
#  '/content/flowers/daffodil/47229602071_a890eb9d68_c.jpg',
#  '/content/flowers/sunflower/15047853109_13df3107ed_c.jpg',
#  '/content/flowers/sunflower/30293903948_59e5ba3dc0_c.jpg',
#  '/content/flowers/calendula/7614995308_111523605d_c.jpg',
# ...

# %%
from PIL import Image
img = Image.open(flwrs[14])
plt.imshow(img)

# %%
np.array(img).shape
# Out:
# (256, 256, 3)

# %%
flwrs[0][-5]
# Out:
# 'c'

# %%
# !pip install cv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2

# %% [markdown]
# **4. from there use appropriate functions to create X_train and Y_train**

# %%
X_train = np.zeros((len(flwrs),256,256),dtype = np.int)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
i=0
for j in flwrs:
    m=cv2.imread(j, cv2.IMREAD_GRAYSCALE)
    new_arr=cv2.resize(m,(256,256))
    X_train[i,:,:]=new_arr
    i=i+1

# %%
new_arr
# Out:
# array([[124, 124, 124, ...,  36,  34,  33],
#        [125, 125, 125, ...,  36,  34,  32],
#        [125, 125, 126, ...,  36,  34,  31],
#        ...,
#        [ 62,  63,  65, ...,  32,  34,  36],
#        [ 68,  69,  70, ...,  34,  35,  35],
#        [ 71,  71,  72, ...,  36,  36,  36]], dtype=uint8)

# %%
ress = cv2.resize(new_arr, dsize=(128, 128), interpolation=cv2.INTER_CUBIC)

# %% [markdown]
# **5. also show the image of X_train[0]**

# %%
display(new_arr[0])
# Out:
# array([124, 124, 124, 123, 120, 117, 114, 112, 110, 109, 108, 108, 108,
#        108, 109, 109, 117, 118, 120, 124, 129, 135, 139, 142, 145, 147,
#        150, 153, 156, 157, 157, 157, 156, 157, 159, 160, 162, 162, 163,
#        163, 170, 170, 170, 170, 169, 169, 169, 169, 167, 167, 166, 165,
#        165, 166, 167, 167, 169, 169, 171, 173, 175, 177, 179, 180, 180,
#        180, 181, 182, 183, 184, 185, 185, 182, 183, 183, 183, 183, 182,
#        181, 180, 177, 177, 177, 177, 177, 176, 176, 176, 174, 175, 176,
#        178, 179, 179, 179, 179, 178, 178, 178, 178, 178, 178, 178, 178,
#        181, 182, 182, 183, 184, 184, 185, 185, 185, 186, 187, 188, 187,
#        185, 182, 180, 180, 180, 179, 178, 176, 173, 171, 170, 167, 165,
#        161, 157, 152, 144, 135, 129, 119, 112, 101,  93,  86,  80,  72,
#         67,  73,  73,  73,  75,  78,  79,  78,  76,  77,  76,  75,  74,
#         73,  72,  71,  71,  67,  67,  66,  66,  65,  65,  64,  64,  63,
# ...

# %%
from PIL import Image
img = Image.fromarray(new_arr[0,:,:])
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-e57c1ba66e70> in <module>()
#       1 from PIL import Image
# ----> 2 img = Image.fromarray(new_arr[0,:,:])
#       3 plt.imshow(img)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
